# %% [markdown]
# <a href="https://colab.research.google.com/github/Reds74/Reds74/blob/main/Algos1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome: ")
mensagem = "Olá, "+nome
print(mensagem)
# Out:
# Digite seu nome: Renê
# Ola, Renê
