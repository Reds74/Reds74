# %% [markdown]
# <a href="https://colab.research.google.com/github/Reds74/Reds74/blob/main/projetopython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a_int = input("Digite o primeiro numero: ")
b_int = input("Digite o segundo numero: ")
a = int(a_int)
b = int(b_int)

print("Resultados das Operações entre ", a, " e ", b,":")
print("Soma: ", a + b)
print("Substração: ", a - b)
print("Multiplicação: ", a * b)
print("Divisão: ", a / b)
print("Divisão inteira: ", a // b)
print("Resto da divisão: ", a % b)
print("Potência: ", a ** b)
# Out:
# Digite o primeiro numero: 9
# Digite o segundo numero: 4
# Resultados das Operações entre  9  e  4 :
# Soma:  13
# Substração:  5
# Multiplicação:  36
# Divisão:  2.25
# Divisão inteira:  2
# Resto da divisão:  1
# Potência:  6561

# %%
# Exemplos condicionais
print("inicio")

num = input("Digite sua idade: ")
idade = int(num)

if idade < 16:
  print("Você não pode votar, você é muito jovem!")
elif idade >= 70:
  print("O voto não é mais obrigatorio, obrigado você já votou muito!")
elif idade >= 18:
  print("O voto é obrigatorio! Não tem para onde fugir.")
else:
  print("O voto é opcional. Recomendo que exerça seu direito, jovem!")
# Out:
# inicio
# Digite sua idade: 70
# O voto não é mais obrigatorio, obrigado você já votou muito!

# %%
#Refinando calculadora

a_int = input("Digite o primeiro numero: ")
b_int = input("Digite o segundo numero: ")
a = int(a_int)
b = int(b_int)
operac = input("Digite a operação (+, - , /, *, //, %, **): ")
op = str(operac)

if operac == "+":
  print("Soma: ", a + b)
elif operac == "-":
  print("Substração: ", a - b)
elif operac == "/":
  print("Divisão: ", a / b)
elif operac == "*":
  print("Multiplicação: ", a * b)
elif operac == "//":
  print("Divisão inteira: ", a // b)
elif operac == "%":
  print("Resto da divisão: ", a % b)
elif operac == "**":
  print("Potência: ", a ** b)
# Out:
# Digite o primeiro numero: 66
# Digite o segundo numero: 9
# Digite a operação (+, - , /, *, //, %, **): %
# Resto da divisão:  3

# %%
#Dicionario de Daados

pessoas = [
    {'nome': 'João', 'idade': 30, 'cidade': 'São Paulo'},
    {'nome': 'Maria', 'idade': 35, 'cidade': 'Rio de Janeiro'},
    {'nome': 'Pedro', 'idade': 25, 'cidade': 'Belo Horizonte'},
    {'nome': 'Ana', 'idade': 28, 'cidade': 'Porto Alegre'}
]

for pessoa in pessoas:
  print(pessoa['nome'], pessoa['idade'], pessoa['cidade'])
# Out:
# João 30 São Paulo
# Maria 35 Rio de Janeiro
# Pedro 25 Belo Horizonte
# Ana 28 Porto Alegre

# %%
#Lista nome e sobrenome

pessoas = []

nome1 = input('Digite o nome da primeira pessoa: ')
snome1 = input('Digite o sobrenome da primeira pessoa: ')
pessoa1 = dict(nome = nome1, sobrenome = snome1)

nome2 = input('Digite o nome da segunda pessoa: ')
snome2 = input('Digite o nome da segunda pessoa: ')
pessoa2 = dict(nome = nome2, sobrenome = snome2)

nome3 = input('Digite o nome da terceira pessoa: ')
snome3 = input('Digite o sobrenome da terceir pessoa: ')
pessoa3 = dict(nome = nome3, sobrenome = snome3)

#adicionando a lista
pessoas.append(pessoa1)
pessoas.append(pessoa2)
pessoas.append(pessoa3)

#exibindo o nome completo de cada pessoa
print("Nome Completo:")
for pessoa in pessoas:
  print(pessoa['nome'], pessoa['sobrenome'])
# Out:
# Digite o nome da primeira pessoa: Paulo
# Digite o sobrenome da primeira pessoa: Paulada
# Digite o nome da segunda pessoa: Ana
# Digite o nome da segunda pessoa: Bolena
# Digite o nome da terceira pessoa: Jorge
# Digite o sobrenome da terceir pessoa: Tadeu
# Nome Completo:
# Paulo Paulada
# Ana Bolena
# Jorge Tadeu

# %%
#Estruturas de repetição

import random

maximo = 10
sorteios_realizados = 0

while sorteios_realizados < maximo:
  sorteios_realizados = sorteios_realizados+1
  print(f"Sorteio {sorteios_realizados}:")
  valor_sortedo = random.randint(1, 10)
  if valor_sortedo==7:
    print("Voçê tirou 7, o jogo acabou!")
    break
  print(f"Valor sortado {valor_sortedo}. Jogue novamente.")
# Out:
# Sorteio 1:
# Valor sortado 9. Jogue novamente.
# Sorteio 2:
# Valor sortado 6. Jogue novamente.
# Sorteio 3:
# Valor sortado 3. Jogue novamente.
# Sorteio 4:
# Valor sortado 1. Jogue novamente.
# Sorteio 5:
# Valor sortado 4. Jogue novamente.
# Sorteio 6:
# Valor sortado 8. Jogue novamente.
# Sorteio 7:
# Valor sortado 6. Jogue novamente.
# Sorteio 8:
# Voçê tirou 7, o jogo acabou!

# %%
#Loops de repetição FOR

compras = ['Arroz', 'Feijão', 'Açucar', 'Cafe', 'Sal', 'Macarrão', 'Batata']

for item in compras:
  if item == 'Café':
    continue
  print(f"Pegar {item}")

print("Fechar no caixa")
# Out:
# Pegar Arroz
# Pegar Feijão
# Pegar Açucar
# Pegar Cafe
# Pegar Sal
# Pegar Macarrão
# Pegar Batata
# Fechar no caixa

# %%
#Loops de repetição WHILE

maximo = 10
atual=0

while atual < maximo:
  atual = atual+1
  print(f"Numero atual: {atual}.")
  if atual%2==0:
    continue
  print("É IMPAR")
print("Fora")
# Out:
# Numero atual: 1.
# É IMPAR
# Numero atual: 2.
# Numero atual: 3.
# É IMPAR
# Numero atual: 4.
# Numero atual: 5.
# É IMPAR
# Numero atual: 6.
# Numero atual: 7.
# É IMPAR
# Numero atual: 8.
# Numero atual: 9.
# É IMPAR
# Numero atual: 10.
# Fora

# %%
#Loops FOR

for x in range(3, 7):
  print(x)

#Percorrendo lista

cores=['azul', 'vermelho', 'verde', 'laranja', 'branco']

for x in range(len(cores)):
  print(cores[x])

#Percorrendo lista de anos

anos = [2019, 2020, 2021]
meses = ['janeiro', 'fevereiro', 'março', 'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro', 'outubro', 'novembro', 'dezembro']

for ano in anos:
  print(f"Inicio do ano: {ano}>>>>>>>>>>>")
  for mes in meses:
    print(f"{mes}/{ano}")
# Out:
# 3
# 4
# 5
# 6
# azul
# vermelho
# verde
# laranja
# branco
# Inicio do ano: 2019>>>>>>>>>>>
# janeiro/2019
# fevereiro/2019
# março/2019
# abril/2019
# maio/2019
# junho/2019
# julho/2019
# agosto/2019
# setembro/2019
# outubro/2019
# novembro/2019
# dezembro/2019
# Inicio do ano: 2020>>>>>>>>>>>
# janeiro/2020
# fevereiro/2020
# março/2020
# abril/2020
# maio/2020
# junho/2020
# julho/2020
# agosto/2020
# setembro/2020
# outubro/2020
# novembro/2020
# dezembro/2020
# Inicio do ano: 2021>>>>>>>>>>>
# janeiro/2021
# fevereiro/2021
# março/2021
# abril/2021
# maio/2021
# junho/2021
# julho/2021
# agosto/2021
# setembro/2021
# outubro/2021
# novembro/2021
# dezembro/2021
